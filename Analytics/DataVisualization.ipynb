# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

time2clear = np.array([
64.4696426391602,
63.2545547485352,
29.0333156585693,
41.2628898620605,
20.4786186218262,
31.0596866607666,
37.4443435668945,
20.7955532073975,
43.9849243164063,
33.6334266662598,
31.609037399292,
70.4901351928711,
25.6178722381592,
35.8988723754883,
68.8060531616211,
32.4020156860352,
32.9004440307617,
36.5595970153809,
27.0175533294678,
35.5514526367188,
55.2729988098145
])

# %%
average = np.mean(time2clear)

# %%
ax = sns.barplot(x=["Alpha version level"], y=[average], width=0.2)
plt.title("Average time to clear the level (in seconds)")
ax.bar_label(ax.containers[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 ax = sns.barplot(x=["Alpha version level"], y=[average], width=0.2)
#       2 plt.title("Average time to clear the level (in seconds)")
# ----> 3 ax.bar_label(average)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2714, in Axes.bar_label(self, container, labels, fmt, label_type, padding, **kwargs)
#    2710     return 1 if x >= 0 else -1
#    2712 _api.check_in_list(['edge', 'center'], label_type=label_type)
# -> 2714 bars = container.patches
#    2715 errorbar = container.errorbar
#    2716 datavalues = container.datavalues
#
# AttributeError: 'numpy.float64' object has no attribute 'patches'
